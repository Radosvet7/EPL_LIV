# %% [markdown]
# # Liverpool before Klopp and under Klopp in EPL
# ![Alt Text](https://www.si.com/.image/t_share/MTY5NzY2MjE4ODI2MjYxNjY1/klopp.jpg)
# ## Exploratory Data Analysis

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/Radosvet7/EPL_LIV/main/results.csv'
df = pd.read_csv(url, encoding='windows-1252')
df.head(5)
# Out:
#     Season              DateTime          HomeTeam        AwayTeam  FTHG  \
# 0  1993-94  1993-08-14T00:00:00Z           Arsenal        Coventry     0
# 1  1993-94  1993-08-14T00:00:00Z       Aston Villa             QPR     4
# 2  1993-94  1993-08-14T00:00:00Z           Chelsea       Blackburn     1
# 3  1993-94  1993-08-14T00:00:00Z         Liverpool  Sheffield Weds     2
# 4  1993-94  1993-08-14T00:00:00Z          Man City           Leeds     1
# 5  1993-94  1993-08-14T00:00:00Z         Newcastle       Tottenham     0
# 6  1993-94  1993-08-14T00:00:00Z            Oldham         Ipswich     0
# 7  1993-94  1993-08-14T00:00:00Z  Sheffield United         Swindon     3
# 8  1993-94  1993-08-14T00:00:00Z       Southampton         Everton     0
# 9  1993-94  1993-08-14T00:00:00Z          West Ham       Wimbledon     0
#
#    FTAG FTR  HTHG  HTAG  HTR  ... HST  AST  HC  AC  HF  AF  HY  AY  HR  AR
# 0     3   A   NaN   NaN  NaN  ... NaN  NaN NaN NaN NaN NaN NaN NaN NaN NaN
# ...

# %%
df['AR'].unique()
# Out:
# array([nan,  0.,  1.,  2.])

# %%
df = df[df['AR'].notnull()]
df.head(5)
# Out:
#        Season              DateTime    HomeTeam       AwayTeam  FTHG  FTAG  \
# 2824  2000-01  2000-08-19T00:00:00Z    Charlton       Man City     4     0
# 2825  2000-01  2000-08-19T00:00:00Z     Chelsea       West Ham     4     2
# 2826  2000-01  2000-08-19T00:00:00Z    Coventry  Middlesbrough     1     3
# 2827  2000-01  2000-08-19T00:00:00Z       Derby    Southampton     2     2
# 2828  2000-01  2000-08-19T00:00:00Z       Leeds        Everton     2     0
# 2829  2000-01  2000-08-19T00:00:00Z   Leicester    Aston Villa     0     0
# 2830  2000-01  2000-08-19T00:00:00Z   Liverpool       Bradford     1     0
# 2831  2000-01  2000-08-19T00:00:00Z  Sunderland        Arsenal     1     0
# 2832  2000-01  2000-08-19T00:00:00Z   Tottenham        Ipswich     3     1
# 2833  2000-01  2000-08-20T00:00:00Z  Man United      Newcastle     2     0
#
#      FTR  HTHG  HTAG HTR  ...   HST  AST   HC   AC    HF    AF   HY   AY   HR  \
# ...

# %%
df = df[df['HomeTeam'] = 'Liverpool' or df['AwayTeam'] = 'Liverpool']
df.head(10)
# Out:
#   Cell In[15], line 1
#     df = df[df['HomeTeam'] = 'Liverpool' or df['AwayTeam'] = 'Liverpool']
#                            ^
# SyntaxError: invalid syntax
